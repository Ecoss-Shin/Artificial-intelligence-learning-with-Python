# %% [markdown]
# # 라이브러리 임포트

# %%
import numpy as np
from PIL import Image, ImageFont, ImageDraw
from PIL.ImageChops import add, subtract, multiply, difference, screen
import PIL.ImageStat as stat
from skimage.io import imread, imsave, imshow, show
from skimage import color, viewer, img_as_float, data
from skimage.transform import SimilarityTransform, warp, swirl
from skimage.util import random_noise
import matplotlib.image as mpimg
import matplotlib.pylab as plt
from scipy import misc

# %% [markdown]
# # PIL을 사용하여 영상 읽기, 저장 및 표시

# %%
im = Image.open("../images/teayeon.jpg") 	# 영상 읽기, 영상 파일 경로 주의
print(im.width, im.height, im.mode, im.format, type(im))
# 453 340 RGB PNG <class 'PIL.PngImagePlugin.PngImageFile'>
#im.show() 									# 영상 표시

im
# Out:
# 554 832 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=554x832 at 0x2CE8FA16160>

# %% [markdown]
# # 명암도 영상

# %%
im_g = im.convert('L') 							# 컬러 영상을 명암도 영상으로 변환
im_g.save('../images/teayeon_gray.jpg') 			# 디스크에 파일 저장
img1 = Image.open("../images/teayeon_gray.jpg") # 디스크의 파일 읽어 표시

img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=554x832 at 0x2CEA6612E10>

# %% [markdown]
# # Matplotlib을 사용하여 영상 읽기, 저장 및 표시

# %%
im = mpimg.imread("../images/teayeon2.png") 	# numpy ndarray 영상 읽기
print(im.shape, im.dtype, type(im)) 		# png 파일은 α 채널 포함
# (960, 1280, 4) float32 <class 'numpy.ndarray'>

plt.figure(figsize=(10,10))
plt.imshow(im), plt.axis('off')
plt.show()
# Out:
# (774, 620, 4) float32 <class 'numpy.ndarray'>

# %%
im1 = im
im1[im1 < 0.5] = 0 						# 어두운 영상 생성

plt.imshow(im1) 						# 영상 그리기
plt.axis('off') 						# 그래프에 축 없음
plt.tight_layout()
plt.savefig("../images/teayeon2_dark.png")				# 영상 저장

im = mpimg.imread("../images/teayeon2_dark.png")		# 저장 영상 읽기
plt.figure(figsize=(10,10))
plt.imshow(im), plt.axis('off'), plt.tight_layout()	# 한 행에 수행 가능
plt.show() # 영상 표시

# %% [markdown]
# # Matplotlib imshow()로 표시하는 동안 보간(Interpolating)

# %%
im = mpimg.imread("../images/teayeon3.jpeg") 				# ndarray 영상 읽기
methods = ['none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'lanczos'] # 보간 방법들

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10), \
						subplot_kw={'xticks': [], 'yticks': []})
fig.subplots_adjust(hspace=0.05, wspace=0.05)
for ax, interp_method in zip(axes.flat, methods):
	ax.imshow(im, interpolation=interp_method)
	ax.set_title(str(interp_method), size=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# # scikit-image를 사용하여 영상 읽기, 저장 및 표시

# %%
im = imread("../images/teayeon.jpg") 			# 영상 읽기
print(im.shape, im.dtype, type(im))
# (362, 486, 3) uint8 <class 'numpy.ndarray'>
hsv = color.rgb2hsv(im) 						# 컬러 공간 변환 (RGB --> HSV)
hsv[:, :, 1] = 0.5 								# 채도 채널 값 변경
im1 = color.hsv2rgb(hsv) 						# 컬러 공간 환원(HSV --> RGB)

imsave('../images/teayeon_hsv.jpg', im1) 		# 영상 저장
im = imread("../images/teayeon_hsv.jpg")
plt.axis('off'), imshow(im)
show()
# Out:
# (832, 554, 3) uint8 <class 'numpy.ndarray'>
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# # imageio 모듈 사용

# %%
import imageio

im = imageio.imread('../images/IU.jpg') # 영상 읽기
print(type(im), im.shape, im.dtype)
# <class 'imageio.core.util.Image'> (225, 225, 3) uint8
plt.imshow(im), plt.axis('off')
plt.show()
# Out:
# <class 'imageio.core.util.Array'> (775, 620, 3) uint8
