# %% [markdown]
# # 라이브러리 임포트

# %%
import numpy as np
from PIL import Image, ImageFont, ImageDraw
from PIL.ImageChops import add, subtract, multiply, difference, screen
import PIL.ImageStat as stat
from skimage.io import imread, imsave, imshow, show
from skimage import color, viewer, img_as_float, data
from skimage.transform import SimilarityTransform, warp, swirl
from skimage.util import random_noise
import matplotlib.image as mpimg
import matplotlib.pylab as plt
from scipy import misc

# %% [markdown]
# # 다양한 영상 유형과 파일 형식 다루기 및 기본 영상 조작

# %%
im = Image.open("../images/Ben1.png") 	# PIL 함수 이용 영상 읽기
print(im.mode) 								# RGB
im.save("../images/Ben1.jpg") 			# Image 객체 내의 save() 함수로 영상 저장
# Out:
# RGBA
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     613     try:
# --> 614         rawmode = RAWMODE[im.mode]
#     615     except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-4314c8c06c4c> in <module>
#       1 im = Image.open("../images/Ben1.png")   # PIL 함수 이용 영상 읽기
#       2 print(im.mode)                                                          # RGB
# ----> 3 im.save("../images/Ben1.jpg")                   # Image 객체 내의 save() 함수로 영상 저장
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2156
#    2157         try:
# -> 2158             save_handler(self, fp, filename)
#    2159         finally:
#    2160             # do what we can to clean up
#
# ~\anaconda3\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     614         rawmode = RAWMODE[im.mode]
#     615     except KeyError as e:
# --> 616         raise OSError("cannot write mode %s as JPEG" % im.mode) from e
#     617
#     618     info = im.encoderinfo
#
# OSError: cannot write mode RGBA as JPEG

# %%
im = Image.open("../images/Ben1.png") 	# PIL 함수 이용 영상 읽기
print(im.mode) 								# RGB
im = im.convert("RGB")
im.save("../images/Ben1.jpg") 			# Image 객체 내의 save() 함수로 영상 저장
# jpg파일은 투명도를 표현할 수 없는 파일 포멧인데 여기에 alpha값을 저장하려고 할 경우 발생
# Out:
# RGBA

# %% [markdown]
# # 한 영상 모드에서 다른 영상 모드로 변환

# %%
im = imread("../images/Ben1.png")
im_g = color.rgb2gray(im)
plt.subplot(121), plt.imshow(im, cmap='gray'), plt.axis('off')
plt.subplot(122), plt.imshow(im_g, cmap='gray'), plt.axis('off')
plt.show()

# %% [markdown]
# # 한 색상 공간에서 다른 색상 공간으로 변환

# %%
im = imread("../images/Ben2.jpg")
im_hsv = color.rgb2hsv(im)
plt.gray() # 명암도 영상으로 표시

plt.figure(figsize=(10,8))
plt.subplot(221), plt.imshow(im_hsv[...,0])
plt.title('h', size=20), plt.axis('off')
plt.subplot(222), plt.imshow(im_hsv[...,1]),
plt.title('s', size=20), plt.axis('off')
plt.subplot(223), plt.imshow(im_hsv[...,2]),
plt.title('v', size=20), plt.axis('off')
plt.subplot(224), plt.axis('off')
plt.show()
